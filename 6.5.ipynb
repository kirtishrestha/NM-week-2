# %% [markdown]
# ### Initial Guess at 4.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Newton-Raphson Method Implementation
def newton_raphson(f, df, x0, tol=1e-10, max_iter=100):
    """Apply the Newton-Raphson method to find a root of the equation f(x) = 0.
    
    Args:
    f (callable): The function for which we are trying to approximate a root f(x)=0.
    df (callable): The derivative of the function f.
    x0 (float): The initial guess for the root.
    tol (float): The tolerance to decide when to stop the iterations.
    max_iter (int): The maximum number of iterations to perform.

    Returns:
    float: The approximated root of the function.
    list: The list of approximations that the algorithm went through (for graphing purposes).
    """
    xn = x0
    iterations = [x0]
    for n in range(0, max_iter):
        fxn = f(xn)
        if abs(fxn) < tol:
            print(f'Found solution after {n} iterations.')
            return xn, iterations
        dfxn = df(xn)
        if dfxn == 0:
            print('Zero derivative. No solution found.')
            return None, iterations
        xn = xn - fxn/dfxn
        iterations.append(xn)
    print('Exceeded maximum iterations. No solution found.')
    return None, iterations

# Define the function and its derivative
def f(x):
    return -2 + 6*x - 4*x**2 + 0.5*x**3

def df(x):
    return 6 - 8*x + 1.5*x**2

# Apply the Newton-Raphson method with an initial guess
initial_guess = 4.2
root, iterations = newton_raphson(f, df, initial_guess)

# Plot the function and the iterations of the Newton-Raphson method
x_values = np.linspace(0, 5, 100)
y_values = f(x_values)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='f(x)')
plt.scatter(iterations, [f(x) for x in iterations], color='green', zorder=5)
plt.plot(iterations, [f(x) for x in iterations], label='Newton-Raphson Iterations', color='blue', linestyle='-')

# Annotate the root
if root is not None:
    plt.scatter(root, f(root), color='red', zorder=5)
    plt.annotate(f'Root: {root:.4f}', xy=(root, f(root)), xytext=(5, 10),
                 textcoords='offset points', arrowprops=dict(arrowstyle='->'))

plt.title('Newton-Raphson Method')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# Output the root and iterations for reference
root, iterations
# Out:
# Found solution after 10 iterations.
# (0.4745724391564829,
#  [4.2,
#   -4.849122807017536,
#   -2.573919351049875,
#   -1.137525717566279,
#   -0.2727384265513706,
#   0.20282989018493064,
#   0.41535371470935145,
#   0.47057416916406436,
#   0.4745519416637334,
#   0.4745724386128767,
#   0.4745724391564829])

# %% [markdown]
# ### Initial Guess at 4.43

# %%
# Apply the Newton-Raphson method with the new initial guess of 4.43
initial_guess_4_43 = 4.43
root_4_43, iterations_4_43 = newton_raphson(f, df, initial_guess_4_43)

# Plot the function and the iterations of the Newton-Raphson method for the new initial guess
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='f(x)')
plt.scatter(iterations_4_43, [f(x) for x in iterations_4_43], color='green', zorder=5)
plt.plot(iterations_4_43, [f(x) for x in iterations_4_43], label='Newton-Raphson Iterations', color='blue', linestyle='-')

# Annotate the root if found
if root_4_43 is not None:
    plt.scatter(root_4_43, f(root_4_43), color='red', zorder=5)
    plt.annotate(f'Root: {root_4_43:.4f}', xy=(root_4_43, f(root_4_43)), xytext=(5, 10),
                 textcoords='offset points', arrowprops=dict(arrowstyle='->'))

plt.title('Newton-Raphson Method with Initial Guess 4.43')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# Output the root and iterations for reference
root_4_43, iterations_4_43
# Out:
# Found solution after 25 iterations.
# (0.47457243915625075,
#  [4.43,
#   -3939.134716977105,
#   -2625.201448390516,
#   -1749.2461988204573,
#   -1165.2764264723808,
#   -775.963835506087,
#   -516.4229930843046,
#   -343.3970898664834,
#   -228.04847021253573,
#   -151.15235271146025,
#   -99.89269202716869,
#   -65.72615362020238,
#   -42.95818513339431,
#   -27.793836719751226,
#   -17.705077324831187,
#   -11.009043609405667,
#   -6.586710031548769,
#   -3.69474661059548,
#   -1.8388990483649492,
#   -0.6882120626592512,
#   -0.018050307875010052,
#   0.32526057904795813,
#   0.4530253046389075,
#   0.47399985276143486,
#   0.47457201549614714,
#   0.47457243915625075])

# %% [markdown]
# ### Tangent Visualizaton of Initial Guesses 4.2 and 4.43

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x)
def f(x):
    return -2 + 6*x - 4*x**2 + 0.5*x**3

# Define the derivative f'(x)
def df(x):
    return 6 - 8*x + 1.5*x**2

# Define the tangent line at a given point x0
def tangent_line(x, x0):
    return df(x0)*(x - x0) + f(x0)

# Create an array of x values
x = np.linspace(1, 6, 400)

# Calculate y values for the function
y = f(x)

# Calculate y values for the tangent lines
tangent1 = tangent_line(x, 4.2)
tangent2 = tangent_line(x, 4.43)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='f(x)')
plt.plot(x, tangent1, label='Tangent at 4.2')
plt.plot(x, tangent2, label='Tangent at 4.43')

# Add a horizontal line at y=0
plt.axhline(0, color='black', linestyle='-')
plt.axvline(0, color='black', linestyle='-')

# Add labels and legend
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Function f(x) and Tangent Lines at Initial Guesses')
plt.grid(True)

plt.legend()
# Show the plot
plt.show()
